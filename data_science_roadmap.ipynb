# %% [markdown]
# # 🚀 Complete Career Transition: Digital Marketing → Data Science
#
# ## 📊 Interactive 12-Month Roadmap with Free Resources
#
# Quick Links: Email | LinkedIn | GitHub
#
# ### What's Inside:
# ✅ 12-month structured learning path
# ✅ 100% free resources with direct links
# ✅ Portfolio projects with code
# ✅ Salary data & market insights
# ✅ Interview preparation materials

# %% [markdown]
# ## 📋 Table of Contents
#
# Click to navigate:
# 1. Setup
# 2. Career Outlook
# 3. Phase 1: Foundations
# 4. Phase 2: Analysis
# 5. Phase 3: ML
# 6. Resources Library
# 7. Job Search

# %%
# Install and import required packages
# !pip install pandas numpy matplotlib seaborn scipy plotly -q

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML, Markdown
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8')
print('✅ Setup complete!')
